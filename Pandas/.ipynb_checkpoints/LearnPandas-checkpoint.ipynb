# %%
import pandas
import numpy

# %%
#Load the data
df = pandas.read_csv('pokedex.csv')
df
# Out:
#       Numero           Nome     Tipo   STipo   HP  Atk  Def  SP Atk  SP Def  \
# 0          1      Bulbasaur    Grass  Poison   45   49   49      65      65
# 1          2        Ivysaur    Grass  Poison   60   62   63      80      80
# 2          3       Venusaur    Grass  Poison   80   82   83     100     100
# 3          3  Mega Venusaur    Grass  Poison   80  100  123     122     120
# 4          4     Charmander     Fire     NaN   39   52   43      60      50
# ...      ...            ...      ...     ...  ...  ...  ...     ...     ...
# 1040     896      Glastrier      Ice     NaN  100  145  130      65     110
# 1041     897      Spectrier    Ghost     NaN  100   65   60     145      80
# 1042     898        Calyrex  Psychic   Grass  100   80   80      80      80
# 1043     898      Ice Rider  Psychic     Ice  100  165  150      85     130
# 1044     898   Shadow Rider  Psychic   Ghost  100   85   80     165     100
#
#       Spd  Total
# 0      45    318
# 1      60    405
# ...

# %%
#Read Headers
df.columns
#Read each Column
df[['Numero','Nome' ]]
#Read each Row
df.head(4)

for index, row in df.iterrows():
    print(index, row['HP'])
#Read a specific location (R,C)
df.iloc[40]
df.iloc[99:103]
# Out:
# 0 45
# 1 60
# 2 80
# 3 80
# 4 39
# 5 58
# 6 78
# 7 78
# 8 78
# 9 44
# 10 59
# 11 79
# 12 79
# 13 45
# 14 50
# 15 60
# 16 40
# 17 45
# 18 65
# 19 65
# 20 40
# 21 63
# 22 83
# 23 83
# 24 30
# 25 30
# 26 55
# 27 75
# 28 40
# 29 65
# 30 35
# 31 60
# 32 35
# 33 45
# 34 60
# 35 60
# 36 50
# 37 50
# 38 75
# 39 75
# 40 55
# 41 70
# 42 90
# 43 46
# 44 61
# 45 81
# 46 70
# 47 95
# 48 38
# 49 38
# 50 73
# 51 73
# 52 115
# 53 140
# 54 40
# 55 75
# 56 45
# 57 60
# 58 75
# 59 35
# 60 60
# 61 60
# 62 70
# 63 10
# 64 10
# 65 35
# 66 35
# 67 40
# 68 40
# 69 50
# 70 65
# 71 65
# 72 50
# 73 80
# 74 40
# 75 65
# 76 55
# 77 90
# 78 40
# 79 65
# 80 90
# 81 25
# 82 40
# 83 55
# 84 55
# 85 70
# 86 80
# 87 90
# 88 50
# 89 65
# 90 80
# 91 40
# 92 80
# 93 40
# 94 40
# 95 55
# 96 55
# 97 80
# 98 80
# 99 50
# 100 50
# 101 65
# 102 65
# 103 90
# 104 90
# 105 95
# 106 95
# 107 95
# 108 25
# 109 50
# 110 52
# 111 52
# 112 35
# 113 60
# 114 65
# 115 90
# 116 80
# 117 80
# 118 105
# 119 105
# 120 30
# 121 50
# ...

# %%
df.loc[df['Tipo'] == "Fire"]
# Out:
#      Numero              Nome  Tipo   STipo   HP  Atk  Def  SP Atk  SP Def  \
# 4         4        Charmander  Fire     NaN   39   52   43      60      50
# 5         5        Charmeleon  Fire     NaN   58   64   58      80      65
# 6         6         Charizard  Fire  Flying   78   84   78     109      85
# 7         6  Mega Charizard X  Fire  Dragon   78  130  111     130      85
# 8         6  Mega Charizard Y  Fire  Flying   78  104   78     159     115
# ..      ...               ...   ...     ...  ...  ...  ...     ...     ...
# 949     813         Scorbunny  Fire     NaN   50   71   40      40      40
# 950     814            Raboot  Fire     NaN   65   86   60      55      60
# 951     815         Cinderace  Fire     NaN   80  116   75      65      75
# 987     850        Sizzlipede  Fire     Bug   50   65   45      50      50
# 988     851       Centiskorch  Fire     Bug  100  115   65      90      90
#
#      Spd  Total
# 4     65    309
# 5     80    405
# ...
